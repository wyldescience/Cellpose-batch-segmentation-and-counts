# %% [markdown]
# <a href="https://colab.research.google.com/github/wyldescience/Cellpose-batch-segmentation-and-counts/blob/main/SAM_crop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Segment Anything Model**
#
# Here I use the [meta](https://github.com/facebookresearch/segment-anything#model-checkpoints) SAM AI (trained on billions of images) that allows for incredible segmentation of images (even by a single click of an object see their [demo](https://segment-anything.com/demo) where you can upload your own image and cut out objects that are perfectly segmented in real time. In this instance I used this model to segment out the filter paper that contains the eggs of *Folsomia candida* to count reproductive output for a study of ageing and lifespan. The reason I wanted to crop out the small piece of filter paper from the background is that the petri dishes were reused between samples and often had stray eggs that I do not want to pick up in my egg counts during segmentation.
# After installment of the appropriate packages, the first chunk of this script is for testing/ working with single images.
# The second chunk is designed to run on batches of images and produces cropped images to an output folder of your choosing. In a number of cases, the first mask detected by the model is not the filter paper I want to retain and thus the region of interest ends up getting cropped out- the first chunk can be used and can alter the integer in the call: "mask = predictor[0]['segmentation']" until the correct cropping has occurred. The script also shuttles processed images to another folder of your choosing.

# %%
# !pip install segment_anything
# !pip install numpy
# !pip install matplotlib
# !pip install pillow

# %% [markdown]
# For running on an individual image file (handy for any that might not work properly when the first mask is not the filter paper (background i.e., edge of petri or other material in some cases makes the filter paper with eggs get cropped out). Try using second mask  "mask = predictor[0]['segmentation']" for problematic images. This cell will produce a plot of the processed and original image.

# %%
import cv2
import numpy as np
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

MODEL_TYPE = "vit_h"
CHECKPOINT_PATH = "/content/drive/Othercomputers/ThinkPad/Desktop/opencv/sam_vit_h_4b8939.pth"
DEVICE = "cuda"

# Load the SAM model
sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device=DEVICE)

# Load the image
image_path = "/content/drive/Othercomputers/ThinkPad/Desktop/Folsomia candida/Data/egg count images/reprocess SAM/I1_F1_O20_CON_R5_10-09-23.jpg"
image = cv2.imread(image_path)

# Display the loaded image using cv2_imshow
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# Create a mask generator using SAM
mask_generator = SamAutomaticMaskGenerator(sam)

# Convert image to RGB format for mask generation
img_arr = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Convert image array to float32
# img_arr = img_arr.astype(np.float32) / 255.0  # Normalize pixel values to [0, 1] range

# Generate masks using the mask generator
predictor = mask_generator.generate(img_arr)

# Choose the first masks
mask = predictor[1]['segmentation']

# Remove background by turning it to white
img_arr[mask == False] = [0, 0, 0]

# Display the modified image using matplotlib
plt.imshow(img_arr)
plt.axis('off')
plt.show()

# %% [markdown]
# **Batch script to run on multiple image files and save output to folder**

# %%
import os
import cv2
import numpy as np
import shutil
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator
import torch
from PIL import Image
from torch.profiler import profile, record_function, ProfilerActivity

def clear_cuda_memory():
    torch.cuda.empty_cache()

# Set environment variable to help with memory issues on GPU
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'garbage_collection_threshold:0.6,max_split_size_mb:512'

MODEL_TYPE = "vit_b"
CHECKPOINT_PATH = "/content/drive/Othercomputers/ThinkPad/Desktop/Folsomia candida/Final Scripts/sam_vit_b_01ec64.pth"
DEVICE = "cuda"

# Input and output directories
input_dir = "/content/drive/Othercomputers/ThinkPad/Desktop/Folsomia candida/Data/egg count images/reprocess SAM"
output_dir = "/content/drive/Othercomputers/ThinkPad/Desktop/Folsomia candida/Data/egg count images/cropped"
processed_dir = "/content/drive/Othercomputers/ThinkPad/Desktop/Folsomia candida/Data/egg count images/processed"

# List all image files in the input directory
image_files = [f for f in os.listdir(input_dir) if f.lower().endswith(('.jpg', '.png', '.tif'))]

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)
os.makedirs(processed_dir, exist_ok=True)

# Process each image file
batch_size = 1  # Adjust the batch size based on your available memory
points_per_batch = 4  # Adjust the points_per_batch FIXED OOM Issue but a lot slower
for i in range(0, len(image_files), batch_size):
    # Load the SAM model for each batch
    sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device=DEVICE)
    sam.eval()

    # Clear GPU memory before processing a new batch
    clear_cuda_memory()

    for j in range(i, min(i + batch_size, len(image_files))):
        image_file = image_files[j]
        image_path = os.path.join(input_dir, image_file)
        image = cv2.imread(image_path)

        print(f"Processing image: {image_file}")

        # Load and process the image on CPU to reduce GPU memory usage
        img_arr = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # Generate masks using the pre-created mask generator
        with torch.no_grad():
            with profile(activities=[ProfilerActivity.CPU, ProfilerActivity.CUDA], record_shapes=True) as prof:
                with record_function("model_inference"):
                    mask_generator = SamAutomaticMaskGenerator(sam, points_per_batch=points_per_batch)
                    predictor = mask_generator.generate(img_arr)
                    mask = predictor[1]['segmentation']  # typically 0 but for erroneous crops try 1

            # Print the memory profile
            print(prof.key_averages().table(sort_by="cuda_memory_usage", row_limit=10))

        # Process the image and mask on CPU
        img_arr[mask == False] = [0, 0, 0]

        # Convert the image to PIL format
        pil_image = Image.fromarray(img_arr)

        # Set the DPI value to 300
        dpi_value = 300
        pil_image.info['dpi'] = (dpi_value, dpi_value)

        # Save the modified image in the output directory using PIL
        # Correct the output path to save in the specified folder
        output_path = os.path.join(output_dir, image_file)
        pil_image.save(output_path, dpi=(dpi_value, dpi_value))

        # Move the original image to the processed originals directory
        processed_image_path = os.path.join(processed_dir, image  _file)
        shutil.move(image_path, processed_image_path)

        # Free memory (No need to delete tensors since we're not using GPU)
        del img_arr, mask, predictor, mask_generator

    # Empty the CUDA cache after processing each batch
    torch.cuda.empty_cache()

print("Processing complete. Images saved in the output directory.")
# Out:
# Processing image: I5_F1_Y25_CON_R4_08-08-23_1.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        23.95%        1.576s       100.00%        6.581s        6.581s       0.000us         0.00%        4.176s        4.176s             1
#                                        aten::lift_fresh         0.01%     585.000us         0.01%     585.000us       0.210us       0.000us         0.00%       0.000us       0.000us          2783
#                                                aten::to         0.25%      16.253ms         8.50%     559.273ms      75.040us       0.000us         0.00%      50.282ms       6.747us          7453
#                                          aten::_to_copy         0.45%      29.302ms         8.38%     551.369ms     109.725us       0.000us         0.00%      51.907ms      10.330us          5025
#                                     aten::empty_strided         0.56%      37.168ms         0.56%      37.168ms       7.038us       0.000us         0.00%       0.000us       0.000us          5281
#                                             aten::copy_         2.27%     149.273ms        10.35%     681.411ms      43.095us     702.498ms        16.82%     702.498ms      44.428us         15812
#                                         cudaMemcpyAsync        20.52%        1.350s        20.52%        1.350s     159.671us       0.000us         0.00%       0.000us       0.000us          8456
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     385.000us         0.01%     385.000us       0.168us          2295
#                                   cudaStreamSynchronize         6.29%     413.768ms         6.29%     413.768ms      51.624us       0.000us         0.00%       0.000us       0.000us          8015
#                                           aten::permute         0.20%      13.288ms         0.22%      14.420ms       4.841us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 6.581s
# Self CUDA time total: 4.176s
#
# Processing image: I6_F2_Y25_CON_R3_10-08-23_1.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        22.08%        1.371s       100.00%        6.207s        6.207s       0.000us         0.00%        4.122s        4.122s             1
#                                        aten::lift_fresh         0.01%     560.000us         0.01%     560.000us       0.233us       0.000us         0.00%       0.000us       0.000us          2405
#                                                aten::to         0.23%      14.038ms         7.91%     491.212ms      71.314us       0.000us         0.00%      53.472ms       7.763us          6888
#                                          aten::_to_copy         0.41%      25.652ms         7.80%     484.081ms     109.645us       0.000us         0.00%      55.801ms      12.639us          4415
#                                     aten::empty_strided         0.48%      29.715ms         0.48%      29.715ms       6.362us       0.000us         0.00%       0.000us       0.000us          4671
#                                             aten::copy_         2.30%     143.045ms        10.04%     623.024ms      41.094us     699.479ms        16.97%     699.479ms      46.137us         15161
#                                         cudaMemcpyAsync        21.63%        1.342s        21.63%        1.342s     179.732us       0.000us         0.00%       0.000us       0.000us          7469
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     353.000us         0.01%     353.000us       0.184us          1917
#                                   cudaStreamSynchronize         5.86%     363.806ms         5.86%     363.806ms      51.378us       0.000us         0.00%       0.000us       0.000us          7081
#                                           aten::permute         0.21%      12.960ms         0.22%      13.822ms       4.640us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 6.207s
# Self CUDA time total: 4.122s
#
# Processing image: I4_F1_Y20_SWI_R3_17-08-23_2.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        21.87%        1.343s       100.00%        6.138s        6.138s       0.000us         0.00%        4.079s        4.079s             1
#                                        aten::lift_fresh         0.01%     632.000us         0.01%     632.000us       0.283us       0.000us         0.00%       0.000us       0.000us          2231
#                                                aten::to         0.22%      13.418ms         9.10%     558.770ms      84.101us       0.000us         0.00%      36.892ms       5.553us          6644
#                                          aten::_to_copy         0.41%      24.939ms         8.99%     551.703ms     133.005us       0.000us         0.00%      37.768ms       9.105us          4148
#                                     aten::empty_strided         0.52%      31.825ms         0.52%      31.825ms       7.226us       0.000us         0.00%       0.000us       0.000us          4404
#                                             aten::copy_         2.32%     142.402ms        11.28%     692.426ms      46.456us     680.536ms        16.68%     680.536ms      45.658us         14905
#                                         cudaMemcpyAsync        19.42%        1.192s        19.42%        1.192s     169.140us       0.000us         0.00%       0.000us       0.000us          7049
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     354.000us         0.01%     354.000us       0.203us          1743
#                                   cudaStreamSynchronize         7.13%     437.404ms         7.13%     437.404ms      65.934us       0.000us         0.00%       0.000us       0.000us          6634
#                                           aten::permute         0.23%      13.846ms         0.24%      15.014ms       5.040us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 6.138s
# Self CUDA time total: 4.079s
#
# Processing image: I2_F2_Y20_CON_R1_17-08-23.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        19.78%        1.169s       100.00%        5.910s        5.910s       0.000us         0.00%        4.118s        4.118s             1
#                                        aten::lift_fresh         0.01%     523.000us         0.01%     523.000us       0.266us       0.000us         0.00%       0.000us       0.000us          1967
#                                                aten::to         0.21%      12.400ms         8.67%     512.659ms      81.777us       0.000us         0.00%      49.750ms       7.936us          6269
#                                          aten::_to_copy         0.38%      22.324ms         8.57%     506.283ms     135.225us       0.000us         0.00%      52.337ms      13.979us          3744
#                                     aten::empty_strided         0.45%      26.795ms         0.45%      26.795ms       6.699us       0.000us         0.00%       0.000us       0.000us          4000
#                                             aten::copy_         2.35%     138.701ms        11.05%     653.236ms      45.007us     689.078ms        16.73%     689.078ms      47.477us         14514
#                                         cudaMemcpyAsync        21.45%        1.268s        21.45%        1.268s     197.848us       0.000us         0.00%       0.000us       0.000us          6408
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     374.000us         0.01%     374.000us       0.253us          1479
#                                   cudaStreamSynchronize         6.84%     404.421ms         6.84%     404.421ms      67.629us       0.000us         0.00%       0.000us       0.000us          5980
#                                           aten::permute         0.23%      13.369ms         0.24%      14.385ms       4.829us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 5.910s
# Self CUDA time total: 4.118s
#
# Processing image: I3_F1_O25_SWI_R3_18-08-23_2.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        22.26%        1.453s       100.00%        6.527s        6.527s       0.000us         0.00%        4.242s        4.242s             1
#                                        aten::lift_fresh         0.01%     548.000us         0.01%     548.000us       0.196us       0.000us         0.00%       0.000us       0.000us          2793
#                                                aten::to         0.28%      18.053ms         8.70%     568.173ms      75.979us       0.000us         0.00%      59.884ms       8.008us          7478
#                                          aten::_to_copy         0.47%      30.624ms         8.56%     558.978ms     111.085us       0.000us         0.00%      62.262ms      12.373us          5032
#                                     aten::empty_strided         0.55%      35.587ms         0.55%      35.587ms       6.730us       0.000us         0.00%       0.000us       0.000us          5288
#                                             aten::copy_         2.31%     150.650ms        10.59%     690.930ms      43.672us     716.999ms        16.90%     716.999ms      45.319us         15821
#                                         cudaMemcpyAsync        20.58%        1.343s        20.58%        1.343s     158.131us       0.000us         0.00%       0.000us       0.000us          8496
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     360.000us         0.01%     360.000us       0.156us          2305
#                                   cudaStreamSynchronize         6.43%     419.990ms         6.43%     419.990ms      52.173us       0.000us         0.00%       0.000us       0.000us          8050
#                                           aten::permute         0.21%      13.882ms         0.23%      15.019ms       5.042us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 6.527s
# Self CUDA time total: 4.242s
#
# Processing image: I3_F1_O25_SWI_R3_05-09-23.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        18.76%        1.090s       100.00%        5.807s        5.807s       0.000us         0.00%        4.100s        4.100s             1
#                                        aten::lift_fresh         0.01%     467.000us         0.01%     467.000us       0.236us       0.000us         0.00%       0.000us       0.000us          1983
#                                                aten::to         0.19%      11.228ms         8.17%     474.609ms      75.768us       0.000us         0.00%      29.492ms       4.708us          6264
#                                          aten::_to_copy         0.38%      21.830ms         8.07%     468.609ms     124.896us       0.000us         0.00%      30.053ms       8.010us          3752
#                                     aten::empty_strided         0.46%      26.809ms         0.46%      26.809ms       6.689us       0.000us         0.00%       0.000us       0.000us          4008
#                                             aten::copy_         2.32%     134.825ms        10.56%     613.137ms      42.352us     677.674ms        16.53%     677.674ms      46.810us         14477
#                                         cudaMemcpyAsync        23.13%        1.343s        23.13%        1.343s     210.145us       0.000us         0.00%       0.000us       0.000us          6391
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     355.000us         0.01%     355.000us       0.237us          1495
#                                   cudaStreamSynchronize         6.39%     370.886ms         6.39%     370.886ms      61.722us       0.000us         0.00%       0.000us       0.000us          6009
#                                           aten::permute         0.23%      13.617ms         0.25%      14.629ms       4.911us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 5.807s
# Self CUDA time total: 4.100s
#
# Processing image: I1_F1_O25_SWI_R5_05-09-23.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        18.85%        1.111s       100.00%        5.892s        5.892s       0.000us         0.00%        4.181s        4.181s             1
#                                        aten::lift_fresh         0.01%     481.000us         0.01%     481.000us       0.245us       0.000us         0.00%       0.000us       0.000us          1963
#                                                aten::to         0.21%      12.114ms         8.27%     487.052ms      78.191us       0.000us         0.00%      47.729ms       7.662us          6229
#                                          aten::_to_copy         0.39%      22.765ms         8.16%     480.886ms     129.584us       0.000us         0.00%      50.624ms      13.642us          3711
#                                     aten::empty_strided         0.46%      26.898ms         0.46%      26.898ms       6.780us       0.000us         0.00%       0.000us       0.000us          3967
#                                             aten::copy_         2.32%     136.760ms        10.62%     625.505ms      43.378us     703.872ms        16.84%     703.872ms      48.812us         14420
#                                         cudaMemcpyAsync        22.92%        1.350s        22.92%        1.350s     213.066us       0.000us         0.00%       0.000us       0.000us          6337
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     362.000us         0.01%     362.000us       0.245us          1475
#                                   cudaStreamSynchronize         6.47%     381.159ms         6.47%     381.159ms      63.878us       0.000us         0.00%       0.000us       0.000us          5967
#                                           aten::permute         0.24%      14.263ms         0.26%      15.472ms       5.194us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 5.892s
# Self CUDA time total: 4.181s
#
# Processing image: I6_F2_Y25_SWI_R5_06-09-23.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        20.25%        1.261s       100.00%        6.228s        6.228s       0.000us         0.00%        4.289s        4.289s             1
#                                        aten::lift_fresh         0.01%     483.000us         0.01%     483.000us       0.213us       0.000us         0.00%       0.000us       0.000us          2271
#                                                aten::to         0.21%      13.277ms         9.00%     560.237ms      83.767us       0.000us         0.00%      51.091ms       7.639us          6688
#                                          aten::_to_copy         0.41%      25.400ms         8.88%     553.257ms     131.540us       0.000us         0.00%      53.175ms      12.643us          4206
#                                     aten::empty_strided         0.47%      29.313ms         0.47%      29.313ms       6.569us       0.000us         0.00%       0.000us       0.000us          4462
#                                             aten::copy_         2.28%     142.002ms        11.16%     695.106ms      46.511us     711.057ms        16.58%     711.057ms      47.578us         14945
#                                         cudaMemcpyAsync        22.45%        1.398s        22.45%        1.398s     195.790us       0.000us         0.00%       0.000us       0.000us          7141
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     402.000us         0.01%     402.000us       0.225us          1783
#                                   cudaStreamSynchronize         7.06%     439.536ms         7.06%     439.536ms      65.194us       0.000us         0.00%       0.000us       0.000us          6742
#                                           aten::permute         0.22%      13.689ms         0.24%      14.777ms       4.960us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 6.228s
# Self CUDA time total: 4.289s
#
# Processing image: I3_F1_O25_CON_R3_08-09-23.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        21.14%        1.306s       100.00%        6.178s        6.178s       0.000us         0.00%        4.172s        4.172s             1
#                                        aten::lift_fresh         0.01%     498.000us         0.01%     498.000us       0.211us       0.000us         0.00%       0.000us       0.000us          2365
#                                                aten::to         0.23%      14.378ms         8.19%     506.085ms      74.260us       0.000us         0.00%      56.017ms       8.220us          6815
#                                          aten::_to_copy         0.43%      26.576ms         8.07%     498.671ms     114.584us       0.000us         0.00%      57.124ms      13.126us          4352
#                                     aten::empty_strided         0.52%      32.236ms         0.52%      32.236ms       6.996us       0.000us         0.00%       0.000us       0.000us          4608
#                                             aten::copy_         2.29%     141.458ms        10.24%     632.400ms      41.931us     710.161ms        17.02%     710.161ms      47.087us         15082
#                                         cudaMemcpyAsync        21.61%        1.335s        21.61%        1.335s     181.432us       0.000us         0.00%       0.000us       0.000us          7358
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     359.000us         0.01%     359.000us       0.191us          1877
#                                   cudaStreamSynchronize         6.14%     379.186ms         6.14%     379.186ms      54.418us       0.000us         0.00%       0.000us       0.000us          6968
#                                           aten::permute         0.23%      14.184ms         0.25%      15.366ms       5.158us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 6.178s
# Self CUDA time total: 4.172s
#
# Processing image: I8_F1_O20_CON_R1_10-09-23.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        25.17%        1.755s       100.00%        6.971s        6.971s       0.000us         0.00%        4.276s        4.276s             1
#                                        aten::lift_fresh         0.01%     581.000us         0.01%     581.000us       0.184us       0.000us         0.00%       0.000us       0.000us          3163
#                                                aten::to         0.29%      20.086ms         8.61%     600.066ms      74.821us       0.000us         0.00%      59.173ms       7.378us          8020
#                                          aten::_to_copy         0.49%      34.266ms         8.46%     589.988ms     104.756us       0.000us         0.00%      62.017ms      11.012us          5632
#                                     aten::empty_strided         0.63%      43.568ms         0.63%      43.568ms       7.399us       0.000us         0.00%       0.000us       0.000us          5888
#                                             aten::copy_         2.19%     152.433ms        10.16%     708.124ms      43.039us     720.690ms        16.85%     720.690ms      43.803us         16453
#                                         cudaMemcpyAsync        19.92%        1.389s        19.92%        1.389s     146.920us       0.000us         0.00%       0.000us       0.000us          9452
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     364.000us         0.01%     364.000us       0.136us          2675
#                                   cudaStreamSynchronize         6.14%     428.198ms         6.14%     428.198ms      47.726us       0.000us         0.00%       0.000us       0.000us          8972
#                                           aten::permute         0.20%      13.715ms         0.21%      14.760ms       4.955us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 6.971s
# Self CUDA time total: 4.276s
#
# Processing image: I1-F1_Y20_SWI_R2_25-07-23_1.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        22.42%        1.425s       100.00%        6.355s        6.355s       0.000us         0.00%        4.218s        4.218s             1
#                                        aten::lift_fresh         0.01%     535.000us         0.01%     535.000us       0.233us       0.000us         0.00%       0.000us       0.000us          2293
#                                                aten::to         0.96%      61.123ms         8.58%     545.349ms      81.033us       0.000us         0.00%      50.045ms       7.436us          6730
#                                          aten::_to_copy         0.42%      26.471ms         8.45%     537.294ms     126.214us       0.000us         0.00%      53.107ms      12.475us          4257
#                                     aten::empty_strided         0.49%      31.285ms         0.49%      31.285ms       6.932us       0.000us         0.00%       0.000us       0.000us          4513
#                                             aten::copy_         2.24%     142.629ms        10.63%     675.303ms      44.951us     708.165ms        16.79%     708.165ms      47.139us         15023
#                                         cudaMemcpyAsync        20.75%        1.319s        20.75%        1.319s     183.810us       0.000us         0.00%       0.000us       0.000us          7175
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     385.000us         0.01%     385.000us       0.213us          1805
#                                   cudaStreamSynchronize         6.60%     419.142ms         6.60%     419.142ms      61.657us       0.000us         0.00%       0.000us       0.000us          6798
#                                           aten::permute         0.23%      14.455ms         0.25%      15.664ms       5.258us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 6.355s
# Self CUDA time total: 4.218s
#
# Processing image: I10_F1_Y20_CON_R1_20-07-23.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        20.65%        1.273s       100.00%        6.162s        6.162s       0.000us         0.00%        4.197s        4.197s             1
#                                        aten::lift_fresh         0.01%     494.000us         0.01%     494.000us       0.219us       0.000us         0.00%       0.000us       0.000us          2259
#                                                aten::to         0.21%      12.702ms         8.15%     502.427ms      75.157us       0.000us         0.00%      47.249ms       7.068us          6685
#                                          aten::_to_copy         0.42%      25.612ms         8.04%     495.304ms     117.733us       0.000us         0.00%      49.148ms      11.682us          4207
#                                     aten::empty_strided         0.51%      31.266ms         0.51%      31.266ms       7.006us       0.000us         0.00%       0.000us       0.000us          4463
#                                             aten::copy_         2.27%     140.137ms        10.26%     632.471ms      42.221us     703.620ms        16.76%     703.620ms      46.971us         14980
#                                         cudaMemcpyAsync        22.38%        1.379s        22.38%        1.379s     193.094us       0.000us         0.00%       0.000us       0.000us          7141
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     346.000us         0.01%     346.000us       0.195us          1771
#                                   cudaStreamSynchronize         6.16%     379.566ms         6.16%     379.566ms      56.567us       0.000us         0.00%       0.000us       0.000us          6710
#                                           aten::permute         0.22%      13.850ms         0.24%      14.923ms       5.009us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 6.162s
# Self CUDA time total: 4.197s
#
# Processing image: I10_F1_Y20_CON_R5_29-07-23_1.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        23.28%        1.522s       100.00%        6.536s        6.536s       0.000us         0.00%        4.223s        4.223s             1
#                                        aten::lift_fresh         0.01%     576.000us         0.01%     576.000us       0.223us       0.000us         0.00%       0.000us       0.000us          2585
#                                                aten::to         0.23%      15.125ms         8.19%     535.588ms      74.949us       0.000us         0.00%      51.174ms       7.161us          7146
#                                          aten::_to_copy         0.45%      29.428ms         8.07%     527.629ms     112.333us       0.000us         0.00%      53.146ms      11.315us          4697
#                                     aten::empty_strided         0.54%      35.355ms         0.54%      35.355ms       7.138us       0.000us         0.00%       0.000us       0.000us          4953
#                                             aten::copy_         2.25%     147.277ms        10.12%     661.256ms      42.819us     713.896ms        16.90%     713.896ms      46.228us         15443
#                                         cudaMemcpyAsync        19.96%        1.305s        19.96%        1.305s     165.365us       0.000us         0.00%       0.000us       0.000us          7890
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     356.000us         0.01%     356.000us       0.170us          2097
#                                   cudaStreamSynchronize         6.04%     395.051ms         6.04%     395.051ms      52.596us       0.000us         0.00%       0.000us       0.000us          7511
#                                           aten::permute         0.23%      15.352ms         0.25%      16.529ms       5.549us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 6.536s
# Self CUDA time total: 4.223s
#
# Processing image: I10_F1_Y20_SWI_R2_16-07-23.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        21.07%        1.306s       100.00%        6.197s        6.197s       0.000us         0.00%        4.220s        4.220s             1
#                                        aten::lift_fresh         0.01%     578.000us         0.01%     578.000us       0.279us       0.000us         0.00%       0.000us       0.000us          2073
#                                                aten::to         0.21%      13.167ms         8.50%     526.599ms      82.281us       0.000us         0.00%      44.169ms       6.901us          6400
#                                          aten::_to_copy         0.40%      24.969ms         8.39%     519.797ms     133.418us       0.000us         0.00%      45.665ms      11.721us          3896
#                                     aten::empty_strided         0.48%      29.659ms         0.48%      29.659ms       7.143us       0.000us         0.00%       0.000us       0.000us          4152
#                                             aten::copy_         2.33%     144.282ms        10.79%     668.508ms      45.691us     699.773ms        16.58%     699.773ms      47.828us         14631
#                                         cudaMemcpyAsync        19.78%        1.226s        19.78%        1.226s     184.895us       0.000us         0.00%       0.000us       0.000us          6630
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     352.000us         0.01%     352.000us       0.222us          1585
#                                   cudaStreamSynchronize         6.58%     407.509ms         6.58%     407.509ms      65.369us       0.000us         0.00%       0.000us       0.000us          6234
#                                           aten::permute         0.25%      15.267ms         0.27%      16.586ms       5.568us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 6.197s
# Self CUDA time total: 4.220s
#
# Processing image: I10_F1_Y20_SWI_R3_21-07-23.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        21.30%        1.360s       100.00%        6.388s        6.388s       0.000us         0.00%        4.264s        4.264s             1
#                                        aten::lift_fresh         0.01%     559.000us         0.01%     559.000us       0.230us       0.000us         0.00%       0.000us       0.000us          2431
#                                                aten::to         0.23%      14.643ms         8.22%     525.292ms      75.669us       0.000us         0.00%      49.214ms       7.089us          6942
#                                          aten::_to_copy         0.46%      29.164ms         8.11%     517.878ms     115.135us       0.000us         0.00%      50.802ms      11.294us          4498
#                                     aten::empty_strided         0.52%      33.051ms         0.52%      33.051ms       6.952us       0.000us         0.00%       0.000us       0.000us          4754
#                                             aten::copy_         2.26%     144.477ms        10.22%     653.171ms      42.683us     720.724ms        16.90%     720.724ms      47.097us         15303
#                                         cudaMemcpyAsync        21.32%        1.362s        21.32%        1.362s     179.314us       0.000us         0.00%       0.000us       0.000us          7597
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     351.000us         0.01%     351.000us       0.181us          1943
#                                   cudaStreamSynchronize         6.15%     392.719ms         6.15%     392.719ms      55.057us       0.000us         0.00%       0.000us       0.000us          7133
#                                           aten::permute         0.23%      14.912ms         0.25%      15.963ms       5.359us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 6.388s
# Self CUDA time total: 4.264s
#
# Processing image: I10_F1_Y20_SWI_R5_21-07-23_1.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        22.97%        1.545s       100.00%        6.727s        6.727s       0.000us         0.00%        4.349s        4.349s             1
#                                        aten::lift_fresh         0.01%     562.000us         0.01%     562.000us       0.210us       0.000us         0.00%       0.000us       0.000us          2679
#                                                aten::to         0.24%      16.264ms         8.99%     604.791ms      82.825us       0.000us         0.00%      58.649ms       8.032us          7302
#                                          aten::_to_copy         0.45%      30.414ms         8.85%     595.573ms     121.869us       0.000us         0.00%      59.676ms      12.211us          4887
#                                     aten::empty_strided         0.55%      37.176ms         0.55%      37.176ms       7.228us       0.000us         0.00%       0.000us       0.000us          5143
#                                             aten::copy_         2.17%     145.791ms        10.76%     723.572ms      46.096us     729.495ms        16.77%     729.495ms      46.474us         15697
#                                         cudaMemcpyAsync        21.24%        1.429s        21.24%        1.429s     173.718us       0.000us         0.00%       0.000us       0.000us          8224
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     352.000us         0.01%     352.000us       0.161us          2191
#                                   cudaStreamSynchronize         6.80%     457.401ms         6.80%     457.401ms      58.974us       0.000us         0.00%       0.000us       0.000us          7756
#                                           aten::permute         0.21%      14.013ms         0.22%      15.041ms       5.049us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 6.727s
# Self CUDA time total: 4.349s
#
# Processing image: I10_F1_Y20_SWI_R5_21-07-23_2.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        20.81%        1.310s       100.00%        6.295s        6.295s       0.000us         0.00%        4.288s        4.288s             1
#                                        aten::lift_fresh         0.01%     511.000us         0.01%     511.000us       0.222us       0.000us         0.00%       0.000us       0.000us          2303
#                                                aten::to         0.23%      14.193ms         8.21%     516.668ms      76.805us       0.000us         0.00%      55.990ms       8.323us          6727
#                                          aten::_to_copy         0.43%      26.840ms         8.09%     509.435ms     120.121us       0.000us         0.00%      58.065ms      13.691us          4241
#                                     aten::empty_strided         0.51%      32.209ms         0.51%      32.209ms       7.162us       0.000us         0.00%       0.000us       0.000us          4497
#                                             aten::copy_         2.22%     139.818ms        10.24%     644.842ms      43.110us     725.968ms        16.93%     725.968ms      48.534us         14958
# ...
#                                     aten::empty_strided         0.43%      25.397ms         0.43%      25.397ms       6.805us       0.000us         0.00%       0.000us       0.000us          3732
#                                             aten::copy_         2.22%     131.761ms        11.07%     657.206ms      46.354us     683.425ms        16.33%     683.425ms      48.203us         14178
#                                         cudaMemcpyAsync        20.57%        1.221s        20.57%        1.221s     206.391us       0.000us         0.00%       0.000us       0.000us          5915
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     353.000us         0.01%     353.000us       0.266us          1327
#                                   cudaStreamSynchronize         7.07%     419.393ms         7.07%     419.393ms      75.539us       0.000us         0.00%       0.000us       0.000us          5552
#                                           aten::permute         0.30%      17.955ms         0.33%      19.471ms       6.536us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 5.936s
# Self CUDA time total: 4.185s
#
# Processing image: I3_F1_Y25_CON_R1_19-07-23_1.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        22.26%        1.513s       100.00%        6.797s        6.797s       0.000us         0.00%        4.370s        4.370s             1
#                                        aten::lift_fresh         0.01%     542.000us         0.01%     542.000us       0.187us       0.000us         0.00%       0.000us       0.000us          2895
#                                                aten::to         0.34%      22.892ms         8.37%     568.608ms      74.640us       0.000us         0.00%      64.564ms       8.475us          7618
#                                          aten::_to_copy         0.51%      34.928ms         8.23%     559.756ms     107.978us       0.000us         0.00%      66.935ms      12.912us          5184
#                                     aten::empty_strided         0.59%      40.201ms         0.59%      40.201ms       7.390us       0.000us         0.00%       0.000us       0.000us          5440
#                                             aten::copy_         2.19%     148.678ms        10.06%     683.741ms      42.844us     739.342ms        16.92%     739.342ms      46.328us         15959
#                                         cudaMemcpyAsync        20.12%        1.368s        20.12%        1.368s     156.499us       0.000us         0.00%       0.000us       0.000us          8740
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     370.000us         0.01%     370.000us       0.154us          2407
#                                   cudaStreamSynchronize         6.03%     409.546ms         6.03%     409.546ms      49.307us       0.000us         0.00%       0.000us       0.000us          8306
#                                           aten::permute         0.26%      17.701ms         0.28%      19.096ms       6.410us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 6.797s
# Self CUDA time total: 4.370s
#
# Processing image: I3_F1_Y25_CON_R1_27-6-23_1.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        19.28%        2.058s       100.00%       10.678s       10.678s       0.000us         0.00%        7.834s        7.834s             1
#                                        aten::lift_fresh         0.01%     588.000us         0.01%     588.000us       0.226us       0.000us         0.00%       0.000us       0.000us          2605
#                                                aten::to         0.25%      26.609ms         5.77%     615.792ms      85.622us       0.000us         0.00%     696.820ms      96.888us          7192
#                                          aten::_to_copy         0.31%      33.448ms         5.67%     605.194ms     127.570us       0.000us         0.00%     713.431ms     150.386us          4744
#                                     aten::empty_strided         0.41%      43.913ms         0.41%      43.913ms       8.783us       0.000us         0.00%       0.000us       0.000us          5000
#                                             aten::copy_         1.34%     143.177ms         6.75%     720.320ms      47.182us        1.547s        19.75%        1.547s     101.333us         15267
#                                         cudaMemcpyAsync        43.67%        4.663s        43.67%        4.663s     582.163us       0.000us         0.00%       0.000us       0.000us          8010
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     386.000us         0.00%     386.000us       0.182us          2117
#                                   cudaStreamSynchronize         4.26%     455.361ms         4.26%     455.361ms      60.153us       0.000us         0.00%       0.000us       0.000us          7570
#                                           aten::permute         0.17%      17.830ms         0.18%      19.366ms       6.501us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 10.678s
# Self CUDA time total: 7.834s
#
# Processing image: I3_F1_Y25_CON_R1_27-6-23_2.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        25.90%        3.005s       100.00%       11.603s       11.603s       0.000us         0.00%        7.788s        7.788s             1
#                                        aten::lift_fresh         0.01%     681.000us         0.01%     681.000us       0.251us       0.000us         0.00%       0.000us       0.000us          2715
#                                                aten::to         0.18%      21.399ms         5.29%     614.356ms      83.620us       0.000us         0.00%     644.369ms      87.705us          7347
#                                          aten::_to_copy         0.30%      34.673ms         5.21%     604.835ms     122.436us       0.000us         0.00%     674.109ms     136.459us          4940
#                                     aten::empty_strided         0.38%      44.416ms         0.38%      44.416ms       8.548us       0.000us         0.00%       0.000us       0.000us          5196
#                                             aten::copy_         1.25%     145.199ms         6.20%     718.974ms      46.433us        1.516s        19.47%        1.516s      97.915us         15484
#                                         cudaMemcpyAsync        39.18%        4.546s        39.18%        4.546s     547.124us       0.000us         0.00%       0.000us       0.000us          8309
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     374.000us         0.00%     374.000us       0.168us          2227
#                                   cudaStreamSynchronize         3.84%     445.482ms         3.84%     445.482ms      56.720us       0.000us         0.00%       0.000us       0.000us          7854
#                                           aten::permute         0.16%      18.139ms         0.17%      19.627ms       6.588us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 11.603s
# Self CUDA time total: 7.788s
#
# Processing image: I3_F1_Y25_CON_R1_27-6-23_3.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        18.02%        1.795s       100.00%        9.962s        9.962s       0.000us         0.00%        7.508s        7.508s             1
#                                        aten::lift_fresh         0.01%     554.000us         0.01%     554.000us       0.262us       0.000us         0.00%       0.000us       0.000us          2113
#                                                aten::to         0.18%      17.524ms         5.46%     544.008ms      84.238us       0.000us         0.00%     713.880ms     110.542us          6458
#                                          aten::_to_copy         0.28%      27.987ms         5.39%     536.480ms     135.441us       0.000us         0.00%     734.844ms     185.520us          3961
#                                     aten::empty_strided         0.36%      36.348ms         0.36%      36.348ms       8.619us       0.000us         0.00%       0.000us       0.000us          4217
#                                             aten::copy_         1.38%     137.589ms         6.67%     664.535ms      46.011us        1.468s        19.55%        1.468s     101.642us         14443
#                                         cudaMemcpyAsync        44.15%        4.398s        44.15%        4.398s     653.094us       0.000us         0.00%       0.000us       0.000us          6734
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     347.000us         0.00%     347.000us       0.214us          1625
#                                   cudaStreamSynchronize         4.15%     413.389ms         4.15%     413.389ms      65.193us       0.000us         0.00%       0.000us       0.000us          6341
#                                           aten::permute         0.18%      18.320ms         0.20%      19.816ms       6.652us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 9.962s
# Self CUDA time total: 7.508s
#
# Processing image: I3_F1_Y25_CON_R3_06-07-23.jpg
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        19.76%        1.203s       100.00%        6.086s        6.086s       0.000us         0.00%        4.216s        4.216s             1
#                                        aten::lift_fresh         0.01%     426.000us         0.01%     426.000us       0.211us       0.000us         0.00%       0.000us       0.000us          2019
#                                                aten::to         0.22%      13.389ms         8.13%     494.986ms      78.507us       0.000us         0.00%      38.606ms       6.123us          6305
#                                          aten::_to_copy         0.43%      26.090ms         8.02%     488.326ms     128.778us       0.000us         0.00%      40.084ms      10.571us          3792
#                                     aten::empty_strided         0.46%      27.995ms         0.46%      27.995ms       6.916us       0.000us         0.00%       0.000us       0.000us          4048
#                                             aten::copy_         2.24%     136.435ms        10.35%     629.990ms      43.478us     700.472ms        16.62%     700.472ms      48.342us         14490
#                                         cudaMemcpyAsync        20.83%        1.268s        20.83%        1.268s     196.436us       0.000us         0.00%       0.000us       0.000us          6454
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     361.000us         0.01%     361.000us       0.236us          1531
#                                   cudaStreamSynchronize         6.30%     383.309ms         6.30%     383.309ms      62.889us       0.000us         0.00%       0.000us       0.000us          6095
#                                           aten::permute         0.29%      17.498ms         0.31%      19.024ms       6.386us       0.000us         0.00%       0.000us       0.000us          2979
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 6.086s
# Self CUDA time total: 4.216s
#
# Processing image: I3_F1_Y25_CON_R3_30-07-23.jpg

# %%
import gc
import torch

torch.cuda.empty_cache()
gc.collect()
# Out:
# 9034570

# %%
# !nvidia-smi
# Out:
# Sun Jan 14 13:32:29 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P0              28W /  70W |   8437MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
import gc
def report_gpu():
   print(torch.cuda.list_gpu_processes())
   gc.collect()
   torch.cuda.empty_cache()

# %%
import gc
gc.collect()
torch.cuda.empty_cache()
